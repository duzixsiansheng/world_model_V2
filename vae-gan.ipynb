# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp39-cp39-win_amd64.whl (7.1 MB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\steve\anaconda3\envs\r\lib\site-packages (from matplotlib) (2.8.1)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp39-cp39-win_amd64.whl (51 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\steve\anaconda3\envs\r\lib\site-packages (from matplotlib) (2.4.7)
# Collecting cycler>=0.10
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: numpy>=1.16 in c:\users\steve\anaconda3\envs\r\lib\site-packages (from matplotlib) (1.19.5)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp39-cp39-win_amd64.whl (2.2 MB)
# Requirement already satisfied: six in c:\users\steve\anaconda3\envs\r\lib\site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.1 pillow-8.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow.keras as keras
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime
import sys
from PIL import Image

# %%
tf.config.experimental.list_physical_devices('GPU')
# Out:
# []

# %%
im_patern = "data/vaegan/"
for i in os.listdir(im_patern):
    im1 = Image.open(im_patern + i)
    im1 = im1.convert("RGB")
    im1.save("data/jpg/" + i.rstrip(".png")+'.jpg')

# %% [markdown]
# ## Input dataset
# Dataset used is celebA : https://www.kaggle.com/jessicali9530/celeba-dataset

# %%
IM_DIM = 64
@tf.function
def im_preprocessing(im_path) :
    im_file = tf.io.read_file(im_path)
    im = tf.io.decode_jpeg(im_file)
    im = tf.image.convert_image_dtype(im, tf.float32)
    #im = tf.image.crop_to_bounding_box(im, 20,0,178,178)
    im = tf.image.resize(im, [IM_DIM, IM_DIM])
    im = tf.image.random_flip_left_right(im)
    return(im)

batch_size = 32
#im_patern = "data/img_align_celeba/img_align_celeba/*.jpg"
im_patern = "data/jpg/*.jpg"
files_dataset = tf.data.Dataset.list_files(im_patern)
im_dataset = files_dataset.map(im_preprocessing)
im_dataset_repeated = im_dataset.repeat()
im_dataset_batch = im_dataset_repeated.batch(batch_size)

for x in im_dataset.take(1) :
    print(x.numpy().shape)
    print("len dataset : ", tf.data.experimental.cardinality(im_dataset).numpy())
    plt.imshow(x)
    
batch_gen = iter(im_dataset_batch)
# Out:
# (64, 64, 3)
# len dataset :  300

# %% [markdown]
# ## Making models

# %%
DEPTH = 32
LATENT_DEPTH = 512
K_SIZE = 5

# %%
def sampling(args):
    mean, logsigma = args
    epsilon = keras.backend.random_normal(shape=keras.backend.shape(mean))
    return mean + tf.exp(logsigma / 2) * epsilon

def encoder():
    input_E = keras.layers.Input(shape=(IM_DIM, IM_DIM, 3))
    
    X = keras.layers.Conv2D(filters=DEPTH*2, kernel_size=K_SIZE, strides=2, padding='same')(input_E)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)

    X = keras.layers.Conv2D(filters=DEPTH*4, kernel_size=K_SIZE, strides=2, padding='same')(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)

    X = keras.layers.Conv2D(filters=DEPTH*8, kernel_size=K_SIZE, strides=2, padding='same')(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)
    
    X = keras.layers.Flatten()(X)
    X = keras.layers.Dense(LATENT_DEPTH)(X)    
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)
    
    mean = keras.layers.Dense(LATENT_DEPTH,activation="tanh")(X)
    logsigma = keras.layers.Dense(LATENT_DEPTH,activation="tanh")(X)
    latent = keras.layers.Lambda(sampling, output_shape=(LATENT_DEPTH,))([mean, logsigma])
    
    kl_loss = 1 + logsigma - keras.backend.square(mean) - keras.backend.exp(logsigma)
    kl_loss = keras.backend.mean(kl_loss, axis=-1)
    kl_loss *= -0.5
    
    return keras.models.Model(input_E, [latent,kl_loss])

def generator():
    input_G = keras.layers.Input(shape=(LATENT_DEPTH,))

    X = keras.layers.Dense(8*8*DEPTH*8)(input_G)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)
    X = keras.layers.Reshape((8, 8, DEPTH * 8))(X)
    
    X = keras.layers.Conv2DTranspose(filters=DEPTH*8, kernel_size=K_SIZE, strides=2, padding='same')(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)

    X = keras.layers.Conv2DTranspose(filters=DEPTH*4, kernel_size=K_SIZE, strides=2, padding='same')(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)
    
    X = keras.layers.Conv2DTranspose(filters=DEPTH, kernel_size=K_SIZE, strides=2, padding='same')(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)
    
    X = keras.layers.Conv2D(filters=3, kernel_size=K_SIZE, padding='same')(X)
    X = keras.layers.Activation('sigmoid')(X)

    return keras.models.Model(input_G, X)

def discriminator():
    input_D = keras.layers.Input(shape=(IM_DIM, IM_DIM, 3))
    
    X = keras.layers.Conv2D(filters=DEPTH, kernel_size=K_SIZE, strides=2, padding='same')(input_D)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)
    
    X = keras.layers.Conv2D(filters=DEPTH*4, kernel_size=K_SIZE, strides=2, padding='same')(input_D)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)
    X = keras.layers.BatchNormalization()(X)

    X = keras.layers.Conv2D(filters=DEPTH*8, kernel_size=K_SIZE, strides=2, padding='same')(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)

    X = keras.layers.Conv2D(filters=DEPTH*8, kernel_size=K_SIZE, padding='same')(X)
    inner_output = keras.layers.Flatten()(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)
    
    X = keras.layers.Flatten()(X)
    X = keras.layers.Dense(DEPTH*8)(X)
    X = keras.layers.BatchNormalization()(X)
    X = keras.layers.LeakyReLU(alpha=0.2)(X)
    
    output = keras.layers.Dense(1)(X)    
    
    return keras.models.Model(input_D, [output, inner_output])

# %% [markdown]
# ## Training

# %%
for x in im_dataset_batch.take(1) :
    test_images = x
test_r = tf.random.normal((batch_size, LATENT_DEPTH))

# %%
E = encoder()
G = generator()
D = discriminator()

# %%
lr=0.0001
#lr=0.0001
E_opt = keras.optimizers.Adam(lr=lr)
G_opt = keras.optimizers.Adam(lr=lr)
D_opt = keras.optimizers.Adam(lr=lr)

inner_loss_coef = 1
normal_coef = 0.1
kl_coef = 0.01

@tf.function
def train_step_vaegan(x):
    lattent_r =  tf.random.normal((batch_size, LATENT_DEPTH))
    with tf.GradientTape(persistent=True) as tape :
        lattent,kl_loss = E(x)
        fake = G(lattent)
        dis_fake,dis_inner_fake = D(fake)
        dis_fake_r,_ = D(G(lattent_r))
        dis_true,dis_inner_true = D(x)

        vae_inner = dis_inner_fake-dis_inner_true
        vae_inner = vae_inner*vae_inner
        
        mean,var = tf.nn.moments(E(x)[0], axes=0)
        var_to_one = var - 1
        
        normal_loss = tf.reduce_mean(mean*mean) + tf.reduce_mean(var_to_one*var_to_one)
        
        kl_loss = tf.reduce_mean(kl_loss)
        vae_diff_loss = tf.reduce_mean(vae_inner)
        f_dis_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(tf.zeros_like(dis_fake), dis_fake))
        r_dis_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(tf.zeros_like(dis_fake_r), dis_fake_r))
        t_dis_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(tf.ones_like(dis_true), dis_true))
        gan_loss = (0.5*t_dis_loss + 0.25*f_dis_loss + 0.25*r_dis_loss)
        vae_loss = tf.reduce_mean(tf.abs(x-fake)) 
        E_loss = vae_diff_loss + kl_coef*kl_loss + normal_coef*normal_loss
        G_loss = inner_loss_coef*vae_diff_loss - gan_loss
        D_loss = gan_loss
    
    E_grad = tape.gradient(E_loss,E.trainable_variables)
    G_grad = tape.gradient(G_loss,G.trainable_variables)
    D_grad = tape.gradient(D_loss,D.trainable_variables)
    del tape
    E_opt.apply_gradients(zip(E_grad, E.trainable_variables))
    G_opt.apply_gradients(zip(G_grad, G.trainable_variables))
    D_opt.apply_gradients(zip(D_grad, D.trainable_variables))

    return [gan_loss, vae_loss, f_dis_loss, r_dis_loss, t_dis_loss, vae_diff_loss, E_loss, D_loss, kl_loss, normal_loss]

step = 0
max_step = 1000
log_freq,img_log_freq = 10, 100
save_freq,save_number_mult = 100, 1000

metrics_names = ["gan_loss", "vae_loss", "fake_dis_loss", "r_dis_loss", "t_dis_loss", "vae_inner_loss", "E_loss", "D_loss", "kl_loss", "normal_loss"]
metrics = []
for m in metrics_names :
    metrics.append(tf.keras.metrics.Mean('m', dtype=tf.float32))

current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir = ('logs/sep_D%dL%d/' % (DEPTH,LATENT_DEPTH)) + current_time 
train_summary_writer = tf.summary.create_file_writer(train_log_dir)
name = ('sep_D%dL%d' % (DEPTH,LATENT_DEPTH))

def save_model() :
    nb = str(step // save_number_mult)
    D.save('saved-models/D_training_' + nb + '.h5')
    G.save('saved-models/G_training_' + nb + '.h5')
    E.save('saved-models/E_training_' + nb + '.h5')

def print_metrics() :
    s = ""
    for name,metric in zip(metrics_names,metrics) :
        s+= " " + name + " " + str(np.around(metric.result().numpy(), 3)) 
    print(f"\rStep : " + str(step) + " " + s, end="", flush=True)
    with train_summary_writer.as_default():
        for name,metric in zip(metrics_names,metrics) :
            tf.summary.scalar(name, metric.result(), step=step)
    for metric in metrics : 
        metric.reset_states()

        
def log_images() :
    with train_summary_writer.as_default():
        lattent,_ = E(test_images)
        fake = G(lattent)
        fake_r = G(test_r)
        tf.summary.image("reconstructed image", fake[:8], step=step, max_outputs=8)
        tf.summary.image("random image", fake_r[:8], step=step, max_outputs=8)
        dis_fake,inner_dis_fake = D(fake)
        dis_fake_r,inner_dis_fake_r = D(fake_r)
        dis_true,inner_dis_true = D(test_images)
        tf.summary.histogram("dis fake", inner_dis_fake, step=step, buckets=20)
        tf.summary.histogram("dis true", inner_dis_true, step=step, buckets=20)
        tf.summary.histogram("dis random", inner_dis_fake_r, step=step, buckets=20)
        tf.summary.histogram("dis lattent", lattent, step=step, buckets=20)
        tf.summary.histogram("dis normal", tf.random.normal((batch_size, LATENT_DEPTH)), step=step, buckets=20)        

for x in batch_gen :
    step += 1
    if not step % log_freq :
        print_metrics()
    if not step % img_log_freq :
        log_images()
    if not step % save_freq :
        save_model()
    
    results = train_step_vaegan(x)
    for metric,result in zip(metrics, results) :
        metric(result)
# Out:
# C:\Users\steve\anaconda3\envs\R\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Step : 100  gan_loss 0.0 vae_loss 0.222 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.013 E_loss 0.025 D_loss 0.0 kl_loss 0.017 normal_loss 0.1263ss 0.093WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 200  gan_loss 0.0 vae_loss 0.151 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.009 E_loss 0.019 D_loss 0.0 kl_loss 0.006 normal_loss 0.101 0.19.095WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 300  gan_loss 0.0 vae_loss 0.162 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.006 E_loss 0.015 D_loss 0.0 kl_loss 0.001 normal_loss 0.09295 0.091WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 400  gan_loss 0.0 vae_loss 0.158 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.005 E_loss 0.015 D_loss 0.0 kl_loss 0.001 normal_loss 0.093WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 500  gan_loss 0.0 vae_loss 0.158 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.005 E_loss 0.014 D_loss 0.0 kl_loss 0.001 normal_loss 0.091WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 600  gan_loss 0.0 vae_loss 0.157 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.005 E_loss 0.014 D_loss 0.0 kl_loss 0.002 normal_loss 0.094WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 700  gan_loss 0.0 vae_loss 0.145 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.004 E_loss 0.014 D_loss 0.0 kl_loss 0.002 normal_loss 0.095WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 800  gan_loss 0.0 vae_loss 0.137 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.004 E_loss 0.013 D_loss 0.0 kl_loss 0.003 normal_loss 0.097WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 900  gan_loss 0.0 vae_loss 0.135 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.003 E_loss 0.013 D_loss 0.0 kl_loss 0.004 normal_loss 0.096WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 1000  gan_loss 0.0 vae_loss 0.136 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.003 E_loss 0.012 D_loss 0.0 kl_loss 0.004 normal_loss 0.094WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 1100  gan_loss 0.0 vae_loss 0.136 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.002 E_loss 0.012 D_loss 0.0 kl_loss 0.003 normal_loss 0.093WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 1200  gan_loss 0.0 vae_loss 0.141 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.002 E_loss 0.012 D_loss 0.0 kl_loss 0.003 normal_loss 0.095WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 1300  gan_loss 0.001 vae_loss 0.138 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.001 vae_inner_loss 0.002 E_loss 0.011 D_loss 0.001 kl_loss 0.003 normal_loss 0.094WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 1400  gan_loss 0.0 vae_loss 0.196 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.013 E_loss 0.022 D_loss 0.0 kl_loss 0.002 normal_loss 0.09495.0944WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 1500  gan_loss 0.0 vae_loss 0.192 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.012 E_loss 0.022 D_loss 0.0 kl_loss 0.004 normal_loss 0.09896WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 1600  gan_loss 0.0 vae_loss 0.193 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.012 E_loss 0.022 D_loss 0.0 kl_loss 0.005 normal_loss 0.099WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 1700  gan_loss 0.0 vae_loss 0.191 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.011 E_loss 0.021 D_loss 0.0 kl_loss 0.006 normal_loss 0.102WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 1800  gan_loss 0.0 vae_loss 0.191 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.011 E_loss 0.021 D_loss 0.0 kl_loss 0.006 normal_loss 0.101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 1900  gan_loss 0.0 vae_loss 0.187 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.01 E_loss 0.02 D_loss 0.0 kl_loss 0.006 normal_loss 0.10132WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 2000  gan_loss 0.0 vae_loss 0.188 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.01 E_loss 0.02 D_loss 0.0 kl_loss 0.007 normal_loss 0.103WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 2100  gan_loss 0.0 vae_loss 0.187 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.009 E_loss 0.02 D_loss 0.0 kl_loss 0.007 normal_loss 0.103WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 2200  gan_loss 0.0 vae_loss 0.186 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.009 E_loss 0.02 D_loss 0.0 kl_loss 0.007 normal_loss 0.1029WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 2300  gan_loss 0.0 vae_loss 0.186 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.009 E_loss 0.019 D_loss 0.0 kl_loss 0.006 normal_loss 0.101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 2400  gan_loss 0.0 vae_loss 0.186 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.009 E_loss 0.019 D_loss 0.0 kl_loss 0.006 normal_loss 0.101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 2500  gan_loss 0.0 vae_loss 0.184 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.008 E_loss 0.018 D_loss 0.0 kl_loss 0.007 normal_loss 0.106WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 2600  gan_loss 0.0 vae_loss 0.183 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.007 E_loss 0.018 D_loss 0.0 kl_loss 0.007 normal_loss 0.106WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 2700  gan_loss 0.0 vae_loss 0.184 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.007 E_loss 0.017 D_loss 0.0 kl_loss 0.006 normal_loss 0.101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 2800  gan_loss 0.0 vae_loss 0.18 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.006 E_loss 0.017 D_loss 0.0 kl_loss 0.007 normal_loss 0.1049WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 2900  gan_loss 0.0 vae_loss 0.179 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.006 E_loss 0.016 D_loss 0.0 kl_loss 0.006 normal_loss 0.101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 3000  gan_loss 0.0 vae_loss 0.177 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.006 E_loss 0.016 D_loss 0.0 kl_loss 0.007 normal_loss 0.102WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 3100  gan_loss 0.0 vae_loss 0.17 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.004 E_loss 0.015 D_loss 0.0 kl_loss 0.006 normal_loss 0.1024WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 3200  gan_loss 0.0 vae_loss 0.163 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.003 E_loss 0.014 D_loss 0.0 kl_loss 0.006 normal_loss 0.10503WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 3300  gan_loss 0.0 vae_loss 0.163 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.003 E_loss 0.013 D_loss 0.0 kl_loss 0.005 normal_loss 0.101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 3400  gan_loss 0.0 vae_loss 0.163 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.003 E_loss 0.013 D_loss 0.0 kl_loss 0.005 normal_loss 0.097WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 3500  gan_loss 0.002 vae_loss 0.151 fake_dis_loss 0.005 r_dis_loss 0.0 t_dis_loss 0.001 vae_inner_loss 0.021 E_loss 0.035 D_loss 0.002 kl_loss 0.026 normal_loss 0.14606WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 3600  gan_loss 0.001 vae_loss 0.175 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.001 vae_inner_loss 0.007 E_loss 0.016 D_loss 0.001 kl_loss 0.004 normal_loss 0.09898WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 3700  gan_loss 0.0 vae_loss 0.171 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.001 vae_inner_loss 0.006 E_loss 0.016 D_loss 0.0 kl_loss 0.005 normal_loss 0.099.09998WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 3800  gan_loss 0.0 vae_loss 0.168 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.006 E_loss 0.016 D_loss 0.0 kl_loss 0.006 normal_loss 0.1989WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 3900  gan_loss 0.0 vae_loss 0.168 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.007 E_loss 0.016 D_loss 0.0 kl_loss 0.005 normal_loss 0.098WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 4000  gan_loss 0.0 vae_loss 0.17 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.007 E_loss 0.017 D_loss 0.0 kl_loss 0.006 normal_loss 0.1021WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 4100  gan_loss 0.0 vae_loss 0.171 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.007 E_loss 0.017 D_loss 0.0 kl_loss 0.005 normal_loss 0.101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 4200  gan_loss 0.0 vae_loss 0.171 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.007 E_loss 0.017 D_loss 0.0 kl_loss 0.004 normal_loss 0.099WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 4300  gan_loss 0.0 vae_loss 0.168 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.007 E_loss 0.017 D_loss 0.0 kl_loss 0.005 normal_loss 0.101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 4400  gan_loss 0.0 vae_loss 0.168 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.007 E_loss 0.017 D_loss 0.0 kl_loss 0.004 normal_loss 0.09703WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 4500  gan_loss 0.0 vae_loss 0.163 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.007 E_loss 0.017 D_loss 0.0 kl_loss 0.006 normal_loss 0.199WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 4600  gan_loss 0.001 vae_loss 0.158 fake_dis_loss 0.002 r_dis_loss 0.001 t_dis_loss 0.001 vae_inner_loss 0.007 E_loss 0.018 D_loss 0.001 kl_loss 0.005 normal_loss 0.101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 4700  gan_loss 0.0 vae_loss 0.145 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.001 vae_inner_loss 0.008 E_loss 0.018 D_loss 0.0 kl_loss 0.007 normal_loss 0.1010203WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 4800  gan_loss 0.001 vae_loss 0.154 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.009 E_loss 0.019 D_loss 0.001 kl_loss 0.007 normal_loss 0.1011101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 4900  gan_loss 0.002 vae_loss 0.141 fake_dis_loss 0.004 r_dis_loss 0.0 t_dis_loss 0.002 vae_inner_loss 0.006 E_loss 0.017 D_loss 0.002 kl_loss 0.007 normal_loss 0.10257WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 5000  gan_loss 1.227 vae_loss 0.156 fake_dis_loss 2.95 r_dis_loss 0.157 t_dis_loss 0.901 vae_inner_loss 0.014 E_loss 0.025 D_loss 1.227 kl_loss 0.01 normal_loss 0.1117WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 5100  gan_loss 0.002 vae_loss 0.563 fake_dis_loss 0.01 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.023 E_loss 0.034 D_loss 0.002 kl_loss 0.009 normal_loss 0.1057.113WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 5200  gan_loss 0.0 vae_loss 0.535 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.023 E_loss 0.034 D_loss 0.0 kl_loss 0.012 normal_loss 0.1137.1104WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 5300  gan_loss 0.0 vae_loss 0.511 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.019 E_loss 0.03 D_loss 0.0 kl_loss 0.013 normal_loss 0.1142WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 5400  gan_loss 0.0 vae_loss 0.507 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.017 E_loss 0.028 D_loss 0.0 kl_loss 0.012 normal_loss 0.11115WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 5500  gan_loss 0.0 vae_loss 0.498 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.016 E_loss 0.028 D_loss 0.0 kl_loss 0.012 normal_loss 0.114WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 5600  gan_loss 0.0 vae_loss 0.49 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.016 E_loss 0.028 D_loss 0.0 kl_loss 0.013 normal_loss 0.1131WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 5700  gan_loss 0.0 vae_loss 0.475 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.015 E_loss 0.027 D_loss 0.0 kl_loss 0.013 normal_loss 0.117WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 5800  gan_loss 0.0 vae_loss 0.461 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.015 E_loss 0.026 D_loss 0.0 kl_loss 0.01 normal_loss 0.1119WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 5900  gan_loss 0.0 vae_loss 0.442 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.014 E_loss 0.025 D_loss 0.0 kl_loss 0.011 normal_loss 0.113WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 6000  gan_loss 0.001 vae_loss 0.419 fake_dis_loss 0.002 r_dis_loss 0.0 t_dis_loss 0.001 vae_inner_loss 0.012 E_loss 0.023 D_loss 0.001 kl_loss 0.012 normal_loss 0.113WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 6100  gan_loss 0.0 vae_loss 0.396 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.013 E_loss 0.024 D_loss 0.0 kl_loss 0.011 normal_loss 0.112.11112WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 6200  gan_loss 0.0 vae_loss 0.379 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.013 E_loss 0.024 D_loss 0.0 kl_loss 0.01 normal_loss 0.119312WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 6300  gan_loss 0.0 vae_loss 0.364 fake_dis_loss 0.0 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.013 E_loss 0.023 D_loss 0.0 kl_loss 0.01 normal_loss 0.1079WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 6400  gan_loss 0.0 vae_loss 0.344 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.0 vae_inner_loss 0.013 E_loss 0.023 D_loss 0.0 kl_loss 0.008 normal_loss 0.106WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 6500  gan_loss 0.001 vae_loss 0.312 fake_dis_loss 0.001 r_dis_loss 0.0 t_dis_loss 0.001 vae_inner_loss 0.012 E_loss 0.022 D_loss 0.001 kl_loss 0.009 normal_loss 0.109WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 6600  gan_loss 0.002 vae_loss 0.224 fake_dis_loss 0.004 r_dis_loss 0.0 t_dis_loss 0.002 vae_inner_loss 0.01 E_loss 0.021 D_loss 0.002 kl_loss 0.01 normal_loss 0.10906WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 6700  gan_loss 0.005 vae_loss 0.143 fake_dis_loss 0.009 r_dis_loss 0.003 t_dis_loss 0.004 vae_inner_loss 0.015 E_loss 0.025 D_loss 0.005 kl_loss 0.006 normal_loss 0.101WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 6800  gan_loss 0.009 vae_loss 0.12 fake_dis_loss 0.013 r_dis_loss 0.01 t_dis_loss 0.008 vae_inner_loss 0.014 E_loss 0.024 D_loss 0.009 kl_loss 0.005 normal_loss 0.09969WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 6900  gan_loss 0.032 vae_loss 0.101 fake_dis_loss 0.069 r_dis_loss 0.01 t_dis_loss 0.024 vae_inner_loss 0.014 E_loss 0.024 D_loss 0.032 kl_loss 0.005 normal_loss 0.1199WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 7000  gan_loss 0.204 vae_loss 0.082 fake_dis_loss 0.548 r_dis_loss 0.021 t_dis_loss 0.124 vae_inner_loss 0.005 E_loss 0.015 D_loss 0.204 kl_loss 0.01 normal_loss 0.1065WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ...
# Step : 15100  gan_loss 0.538 vae_loss 0.014 fake_dis_loss 0.781 r_dis_loss 0.317 t_dis_loss 0.526 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.538 kl_loss 0.021 normal_loss 0.092WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 15200  gan_loss 0.478 vae_loss 0.012 fake_dis_loss 0.763 r_dis_loss 0.236 t_dis_loss 0.457 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.478 kl_loss 0.027 normal_loss 0.0925WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 15300  gan_loss 0.07 vae_loss 0.017 fake_dis_loss 0.098 r_dis_loss 0.05 t_dis_loss 0.065 vae_inner_loss 0.002 E_loss 0.012 D_loss 0.07 kl_loss 0.014 normal_loss 0.095094WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 15400  gan_loss 0.854 vae_loss 0.014 fake_dis_loss 1.663 r_dis_loss 0.404 t_dis_loss 0.674 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.854 kl_loss 0.025 normal_loss 0.0912WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 15500  gan_loss 0.534 vae_loss 0.011 fake_dis_loss 0.919 r_dis_loss 0.236 t_dis_loss 0.491 vae_inner_loss 0.0 E_loss 0.01 D_loss 0.534 kl_loss 0.027 normal_loss 0.093931WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 15600  gan_loss 0.575 vae_loss 0.013 fake_dis_loss 0.899 r_dis_loss 0.449 t_dis_loss 0.476 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.575 kl_loss 0.018 normal_loss 0.099WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 15700  gan_loss 1.02 vae_loss 0.012 fake_dis_loss 1.826 r_dis_loss 0.686 t_dis_loss 0.785 vae_inner_loss 0.001 E_loss 0.01 D_loss 1.02 kl_loss 0.024 normal_loss 0.093922WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 15800  gan_loss 0.523 vae_loss 0.014 fake_dis_loss 0.909 r_dis_loss 0.232 t_dis_loss 0.475 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.523 kl_loss 0.025 normal_loss 0.0895WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 15900  gan_loss 0.548 vae_loss 0.011 fake_dis_loss 0.919 r_dis_loss 0.281 t_dis_loss 0.496 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.548 kl_loss 0.025 normal_loss 0.0942WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 16000  gan_loss 0.42 vae_loss 0.011 fake_dis_loss 0.652 r_dis_loss 0.272 t_dis_loss 0.378 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.42 kl_loss 0.022 normal_loss 0.091945WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 16100  gan_loss 0.524 vae_loss 0.013 fake_dis_loss 0.779 r_dis_loss 0.323 t_dis_loss 0.497 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.524 kl_loss 0.019 normal_loss 0.092WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 16200  gan_loss 0.1 vae_loss 0.018 fake_dis_loss 0.147 r_dis_loss 0.051 t_dis_loss 0.101 vae_inner_loss 0.001 E_loss 0.011 D_loss 0.1 kl_loss 0.015 normal_loss 0.093092WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 16300  gan_loss 0.246 vae_loss 0.015 fake_dis_loss 0.511 r_dis_loss 0.12 t_dis_loss 0.176 vae_inner_loss 0.001 E_loss 0.011 D_loss 0.246 kl_loss 0.018 normal_loss 0.0931WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 16400  gan_loss 0.592 vae_loss 0.012 fake_dis_loss 0.836 r_dis_loss 0.37 t_dis_loss 0.581 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.592 kl_loss 0.021 normal_loss 0.09122WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 16500  gan_loss 0.44 vae_loss 0.012 fake_dis_loss 0.58 r_dis_loss 0.271 t_dis_loss 0.454 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.44 kl_loss 0.021 normal_loss 0.0939223WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 16600  gan_loss 0.524 vae_loss 0.013 fake_dis_loss 0.664 r_dis_loss 0.204 t_dis_loss 0.614 vae_inner_loss 0.0 E_loss 0.01 D_loss 0.524 kl_loss 0.026 normal_loss 0.088913WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 16700  gan_loss 0.522 vae_loss 0.015 fake_dis_loss 0.956 r_dis_loss 0.373 t_dis_loss 0.38 vae_inner_loss 0.001 E_loss 0.011 D_loss 0.522 kl_loss 0.017 normal_loss 0.0931WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 16800  gan_loss 0.648 vae_loss 0.01 fake_dis_loss 1.014 r_dis_loss 0.423 t_dis_loss 0.577 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.648 kl_loss 0.022 normal_loss 0.0923WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 16900  gan_loss 0.536 vae_loss 0.012 fake_dis_loss 0.833 r_dis_loss 0.326 t_dis_loss 0.492 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.536 kl_loss 0.023 normal_loss 0.0923WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 17000  gan_loss 0.293 vae_loss 0.014 fake_dis_loss 0.461 r_dis_loss 0.156 t_dis_loss 0.277 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.293 kl_loss 0.031 normal_loss 0.0891WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 17100  gan_loss 0.339 vae_loss 0.014 fake_dis_loss 0.454 r_dis_loss 0.153 t_dis_loss 0.375 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.339 kl_loss 0.021 normal_loss 0.092WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 17200  gan_loss 0.953 vae_loss 0.012 fake_dis_loss 2.194 r_dis_loss 0.446 t_dis_loss 0.586 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.953 kl_loss 0.022 normal_loss 0.091WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 17300  gan_loss 0.217 vae_loss 0.024 fake_dis_loss 0.227 r_dis_loss 0.108 t_dis_loss 0.267 vae_inner_loss 0.001 E_loss 0.011 D_loss 0.217 kl_loss 0.016 normal_loss 0.091WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Step : 17330  gan_loss 0.114 vae_loss 0.022 fake_dis_loss 0.227 r_dis_loss 0.026 t_dis_loss 0.102 vae_inner_loss 0.001 E_loss 0.01 D_loss 0.114 kl_loss 0.03 normal_loss 0.09091
